# %% [markdown]
# # 6. OCR文本错漏频发？结合LLM纠错，让图像文本也能精准使用

# %% [markdown]
# ### 1.1 错误类型分析
#
# OCR识别错误通常可以分为以下几类：
#
# - **字符识别错误**
# - **文字遗漏**
# - **多字重复**
# - **格式混乱**
# - **特殊符号识别错误**
#
# 这些错误往往源于以下几个方面：
#
# - **图像质量不佳**
# - **字体样式复杂**
# - **背景干扰**
# - **OCR算法限制**
#
# ### 1.2 传统解决方案的局限性
#
# 传统的OCR优化方法主要包括：
#
# - **图像预处理**
# - **后处理规则**
# - **模型微调**

# %% [markdown]
# ## 结合 LLM 进行文本纠错的新思路
# - 充分发挥 LLM 的语言建模能力
# - OCR + LLM 的协同流程
#
# 我们可以将整个OCR处理流程分为两个阶段：
#
# 1. OCR识别阶段：使用 PaddleOCR 5 对输入图像进行识别，得到初步的文本结果。
# 2. LLM纠错阶段：将OCR输出的文本送入大语言模型，由其进行语义级别的纠错和优化。
#
# 具体流程如下：
# [图像] → [PaddleOCR 5] → [初步OCR文本] → [LLM纠错] → [最终文本]

# %% [markdown]
# # 实战操作

# %% [markdown]
# [快速安装飞桨平台工具](https://www.paddlepaddle.org.cn/install/quick?docurl=undefined)

# %%
# 安装 PaddleOCR
! pip install paddleocr
# Out:
# Looking in indexes: https://pypi.mirrors.ustc.edu.cn/simple
# Requirement already satisfied: paddleocr in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (3.1.0)
# Requirement already satisfied: paddlex>=3.1.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.1.1)
# Requirement already satisfied: PyYAML>=6 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddleocr) (4.14.0)
# Requirement already satisfied: chardet in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (5.2.0)
# Requirement already satisfied: colorlog in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (6.9.0)
# Requirement already satisfied: filelock in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.18.0)
# Requirement already satisfied: huggingface-hub in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.33.1)
# Requirement already satisfied: numpy>=1.24 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.3.1)
# Requirement already satisfied: packaging in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (24.2)
# Requirement already satisfied: pandas>=1.3 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.2.3)
# Requirement already satisfied: pillow in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (11.2.1)
# Requirement already satisfied: prettytable in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.16.0)
# Requirement already satisfied: py-cpuinfo in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (9.0.0)
# Requirement already satisfied: pydantic>=2 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.11.7)
# Requirement already satisfied: requests in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.32.4)
# Requirement already satisfied: ruamel.yaml in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.18.14)
# Requirement already satisfied: ujson in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (5.10.0)
# Requirement already satisfied: ftfy in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (6.3.1)
# Requirement already satisfied: imagesize in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.4.1)
# Requirement already satisfied: langchain>=0.2 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.3.26)
# Requirement already satisfied: langchain-community>=0.2 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.3.26)
# Requirement already satisfied: langchain-core in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.3.67)
# Requirement already satisfied: langchain-openai>=0.1 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.3.27)
# Requirement already satisfied: lxml in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (6.0.0)
# Requirement already satisfied: openai>=1.63 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.93.0)
# Requirement already satisfied: opencv-contrib-python==4.10.0.84 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (4.10.0.84)
# Requirement already satisfied: openpyxl in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.1.5)
# Requirement already satisfied: premailer in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.10.0)
# Requirement already satisfied: pyclipper in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.3.0.post6)
# Requirement already satisfied: pypdfium2>=4 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (4.30.1)
# Requirement already satisfied: scikit-learn in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.7.0)
# Requirement already satisfied: shapely in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.1.1)
# Requirement already satisfied: tokenizers>=0.19 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.21.2)
# Requirement already satisfied: einops in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.8.1)
# Requirement already satisfied: GPUtil>=1.4 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.4.0)
# Requirement already satisfied: Jinja2 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.1.6)
# Requirement already satisfied: regex in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2024.11.6)
# Requirement already satisfied: tiktoken in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (4.13.4)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.4.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langchain-core->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langchain-core->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from pydantic>=2->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from pydantic>=2->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from pydantic>=2->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from requests->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from requests->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from requests->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from requests->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2025.6.15)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.12.13)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.10.0)
# Requirement already satisfied: sniffio in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (4.67.1)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.63->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.16.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langsmith>=0.1.17->langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langsmith>=0.1.17->langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from langsmith>=0.1.17->langchain>=0.2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from pandas>=1.3->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from pandas>=1.3->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from pandas>=1.3->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from huggingface-hub->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from huggingface-hub->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.1.5)
# Requirement already satisfied: soupsieve>1.2 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from beautifulsoup4->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.7)
# Requirement already satisfied: wcwidth in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from ftfy->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from Jinja2->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.0.2)
# Requirement already satisfied: et-xmlfile in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from openpyxl->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.0.0)
# Requirement already satisfied: cssselect in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from premailer->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.3.0)
# Requirement already satisfied: cssutils in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from premailer->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (2.11.1)
# Requirement already satisfied: cachetools in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from premailer->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (6.1.0)
# Requirement already satisfied: more-itertools in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from cssutils->premailer->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (10.7.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from ruamel.yaml->paddlex>=3.1.0->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (0.2.12)
# Requirement already satisfied: scipy>=1.8.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from scikit-learn->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from scikit-learn->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/miniconda3/envs/rag50/lib/python3.12/site-packages (from scikit-learn->paddlex[ie,multimodal,ocr,trans]>=3.1.0->paddleocr) (3.6.0)

# %% [markdown]
# ![OCR 示例图片](https://paddle-model-ecology.bj.bcebos.com/paddlex/imgs/demo_image/general_ocr_002.png  "通用 OCR 示例图像")

# %%
# 运行 PP-OCRv5 推理
! paddleocr ocr -i https://paddle-model-ecology.bj.bcebos.com/paddlex/imgs/demo_image/general_ocr_002.png --use_doc_orientation_classify False --use_doc_unwarping False --use_textline_orientation False 

# 运行 PP-ChatOCRv4 推理前，需要先获得千帆API Key
# paddleocr pp_chatocrv4_doc -i https://paddle-model-ecology.bj.bcebos.com/paddlex/imgs/demo_image/vehicle_certificate-1.png -k 驾驶室准乘人数 --qianfan_api_key your_api_key --use_doc_orientation_classify False --use_doc_unwarping False 

# 查看 "paddleocr ocr" 详细参数
# paddleocr ocr --help

# %%
# PP-OCRv5 示例
from paddleocr import PaddleOCR
# 初始化 PaddleOCR 实例
ocr = PaddleOCR(
    use_doc_orientation_classify=False,
    use_doc_unwarping=False,
    use_textline_orientation=False)
# 对示例图像执行 OCR 推理 
result = ocr.predict(
    input="https://paddle-model-ecology.bj.bcebos.com/paddlex/imgs/demo_image/general_ocr_002.png")
# 可视化结果并保存 json 结果
for res in result:
    res.print()
    res.save_to_img("output")
    res.save_to_json("output")
# Out:
# MKL-DNN is not available. Using `paddle` instead.
# Creating model: ('PP-OCRv5_server_det', None)
# Using official model (PP-OCRv5_server_det), the model files will be automatically downloaded and saved in /Users/wilson/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 4360.74it/s]
# Creating model: ('PP-OCRv5_server_rec', None)
# Using official model (PP-OCRv5_server_rec), the model files will be automatically downloaded and saved in /Users/wilson/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 4747.37it/s]
# Connecting to https://paddle-model-ecology.bj.bcebos.com/paddlex/imgs/demo_image/general_ocr_002.png ...
# Downloading general_ocr_002.png ...
# [==================================================] 100.00%
# {'res': {'input_path': '/Users/wilson/.paddlex/predict_input/general_ocr_002.png', 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': False}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': False, 'use_doc_unwarping': False}, 'angle': -1}, 'dt_polys': array([[[152,  22],
#         ...,
#         [153,  77]],
#
#        ...,
#
#        [[ 99, 455],
#         ...,
#         [ 99, 480]]], shape=(33, 4, 2), dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([-1, ..., -1], shape=(33,)), 'text_rec_score_thresh': 0.0, 'rec_texts': ['登机牌', 'BOARDING', 'PASS', '日期DATE', '舱位', 'CLASS', '序号', 'SERIALNO.', '座位号', 'SEAT NO.', '航班FLIGHT', 'MU 2379 03DEC', 'W', '035', '始发地', 'FROM', '登机口', 'GATE', '登机时间', 'BDT', '目的地TO', '福州', 'TAIYUAN', 'G11', 'FUZHOU', '身份识别IDNO.', '姓名NAME', 'ZHANGQIWEI', '票号TKTNO.', '张祺伟', '票价FARE', 'ETKT7813699238489/1', '登机口于起飞前1O分钟关闭GATESCLOSE1OMINUTESBEFORE DEPARTURETIME'], 'rec_scores': array([0.997154  , ..., 0.97328258], shape=(33,)), 'rec_polys': array([[[152,  22],
#         ...,
#         [153,  77]],
#
#        ...,
#
#        [[ 99, 455],
#         ...,
#         [ 99, 480]]], shape=(33, 4, 2), dtype=int16), 'rec_boxes': array([[152, ...,  77],
#        ...,
#        [ 99, ..., 480]], shape=(33, 4), dtype=int16)}}

# %% [markdown]
# ![PP-OCRv5](https://paddle-model-ecology.bj.bcebos.com/paddlex/PaddleX3.0/AIStudio/application_help/demo_images/algorithm_ppocrv5.png)

# %% [markdown]
# ![PP-ChatOCRV4](https://paddle-model-ecology.bj.bcebos.com/paddlex/PaddleX3.0/AIStudio/application_help/demo_images/algorithm_ppchatocrv4.png)

# %% [markdown]
# ![ocr_result](https://paddle-model-ecology.bj.bcebos.com/paddlex/imgs/demo_image/vehicle_certificate-1.png)

# %%
# PP-ChatOCRv4 示例
from paddleocr import PPChatOCRv4Doc
import  os
BCE_API_KEY = os.environ.get("BCE_API_KEY")

chat_bot_config = {
    "module_name": "chat_bot",
    "model_name": "ernie-4.0-8k",
    "base_url": "https://qianfan.baidubce.com/v2",
    "api_type": "openai",
    "api_key": BCE_API_KEY,  # your api_key
}

retriever_config = {
    "module_name": "retriever",
    "model_name": "embedding-v1",
    "base_url": "https://qianfan.baidubce.com/v2",
    "api_type": "qianfan",
    "api_key": BCE_API_KEY,  # your api_key
}

pipeline = PPChatOCRv4Doc(
    use_doc_orientation_classify=False,
    use_doc_unwarping=False
)

visual_predict_res = pipeline.visual_predict(
    input="https://paddle-model-ecology.bj.bcebos.com/paddlex/imgs/demo_image/vehicle_certificate-1.png",
    use_common_ocr=True,
    use_seal_recognition=True,
    use_table_recognition=True,
)

mllm_predict_info = None
use_mllm = False
# 如果使用多模态大模型，需要启动本地 mllm 服务，可以参考文档：https://github.com/PaddlePaddle/PaddleX/blob/release/3.0/docs/pipeline_usage/tutorials/vlm_pipelines/doc_understanding.md 进行部署，并更新 mllm_chat_bot_config 配置。
if use_mllm:
    mllm_chat_bot_config = {
        "module_name": "chat_bot",
        "model_name": "PP-DocBee",
        "base_url": "http://127.0.0.1:8080/",  # your local mllm service url
        "api_type": "openai",
        "api_key": "api_key",  # your api_key
    }

    mllm_predict_res = pipeline.mllm_pred(
        input="https://paddle-model-ecology.bj.bcebos.com/paddlex/imgs/demo_image/vehicle_certificate-1.png",
        key_list=["驾驶室准乘人数"],
        mllm_chat_bot_config=mllm_chat_bot_config,
    )
    mllm_predict_info = mllm_predict_res["mllm_res"]

visual_info_list = []
for res in visual_predict_res:
    visual_info_list.append(res["visual_info"])
    layout_parsing_result = res["layout_parsing_result"]

vector_info = pipeline.build_vector(
    visual_info_list, flag_save_bytes_vector=True, retriever_config=retriever_config
)
chat_result = pipeline.chat(
    key_list=["驾驶室准乘人数"],
    visual_info=visual_info_list,
    vector_info=vector_info,
    mllm_predict_info=mllm_predict_info,
    chat_bot_config=chat_bot_config,
    retriever_config=retriever_config,
)

print(chat_result)
# Out:
# MKL-DNN is not available. Using `paddle` instead.
# Creating model: ('RT-DETR-H_layout_3cls', None)
# Using official model (RT-DETR-H_layout_3cls), the model files will be automatically downloaded and saved in /Users/wilson/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 3018.21it/s]
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Using official model (PP-LCNet_x1_0_textline_ori), the model files will be automatically downloaded and saved in /Users/wilson/.paddlex/official_models.
# Fetching 8 files: 100%|██████████| 8/8 [00:00<00:00, 3872.41it/s]
# Creating model: ('PP-OCRv4_server_det', None)
# Using official model (PP-OCRv4_server_det), the model files will be automatically downloaded and saved in /Users/wilson/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 3181.12it/s]
# Creating model: ('PP-OCRv4_server_rec_doc', None)
# Using official model (PP-OCRv4_server_rec_doc), the model files will be automatically downloaded and saved in /Users/wilson/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 2695.57it/s]
# Creating model: ('PP-OCRv4_server_seal_det', None)
# Using official model (PP-OCRv4_server_seal_det), the model files will be automatically downloaded and saved in /Users/wilson/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 2971.87it/s]
# Creating model: ('PP-OCRv4_server_rec_doc', None)
# Using official model (PP-OCRv4_server_rec_doc), the model files will be automatically downloaded and saved in /Users/wilson/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 4909.45it/s]
# Creating model: ('SLANet_plus', None)
# Using official model (SLANet_plus), the model files will be automatically downloaded and saved in /Users/wilson/.paddlex/official_models.
# Fetching 6 files: 100%|██████████| 6/6 [00:00<00:00, 7334.84it/s]
# Connecting to https://paddle-model-ecology.bj.bcebos.com/paddlex/imgs/demo_image/vehicle_certificate-1.png ...
# Downloading vehicle_certificate-1.png ...
# [==================================================] 100.00%
# {'chat_res': {'驾驶室准乘人数': '2'}}
